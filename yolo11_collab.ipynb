# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewstheBuilder/VideoSemanticSearch_JiuJitsu/blob/main/yolo11_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.2/225.8 GB disk)

# %%
# Load YOLO11n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11x-pose.pt')  # load a pretrained YOLO pose model
# model.train(data='coco8-pose.yaml', epochs=3)  # train the model

# %%
results = model('/content/video_1_frame_14610.jpg')  # predict on an image
# Out:
# image 1/1 /content/video_1_frame_14610.jpg: 384x640 1 person, 3219.3ms
# Speed: 3.6ms preprocess, 3219.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
